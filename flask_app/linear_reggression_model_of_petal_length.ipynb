# %%
import pickle
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
iris= datasets.load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# sepal length, sepal width and petal width
X = df.iloc[:, [0,1,3]]
# petal length
Y = df.iloc[:, [2]]
# spliting the data
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# building model
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print('The intercept is {} and the coef are {}'.format(regressor.intercept_, regressor.coef_))
# Out:
# The intercept is [-0.26533136] and the coef are [[ 0.7005897  -0.61042077  1.48167646]]

# %%
ypred = regressor.predict(xtest).tolist()
ypred_ = [val for sublist in ypred for val in sublist]


ytest['predicted'] = ypred_
ytest
# Out:
# C:\Users\Jeffery\AppData\Local\Temp/ipykernel_9588/798841458.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest['predicted'] = ypred_
#      petal length (cm)  predicted
# 114                5.1   5.644934
# 62                 4.0   4.076958
# 33                 1.4   1.320480
# 107                6.3   5.745771
# 7                  1.5   1.458522
# 100                6.0   5.838186
# 40                 1.3   1.545647
# 86                 4.7   4.758830
# 76                 4.8   4.863848
# 71                 4.0   4.225267
# 134                5.6   4.495519
# 51                 4.5   4.487611
# 73                 4.7   4.077099
# 54                 4.6   4.801838
# 63                 4.7   4.312393
# ...

# %%
# pack the model with pickle
with open('model.pkl', 'wb') as files:
    pickle.dump(regressor, files)
